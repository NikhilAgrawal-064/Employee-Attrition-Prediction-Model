# %%
# Group-17 -(Project Employee Attrition Prediction) Members - Nikhil Agrawal, Govind upadhyay, ansh dubey, rohit choudhary, vikas kumar

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('employee_attrition_data.csv')
df
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
df.dropna()
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
# ...

# %%
df.describe()
# Out:
#        Employee_ID          Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000  1000.000000       1000.000000         1000.000000
# mean    499.500000    42.205000          5.605000            0.505995
# std     288.819436    10.016452          2.822223            0.289797
# min       0.000000    25.000000          1.000000            0.001376
# 25%     249.750000    33.000000          3.000000            0.258866
# 50%     499.500000    43.000000          6.000000            0.505675
# 75%     749.250000    51.000000          8.000000            0.761135
# max     999.000000    59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# ...

# %%
df['Attrition'] = df['Attrition'].replace({0:'No',1:'Yes'})

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     505
# Yes    495
# Name: count, dtype: int64

# %%
for column in df.columns:
    if df[column].dtype == object:
        print (str(column) + ':' + str(df[column].unique()))
        print (df[column].value_counts())
        print("------------------------")
# Out:
# Gender:['Male' 'Female']
# Gender
# Male      506
# Female    494
# Name: count, dtype: int64
# ------------------------
# Department:['Marketing' 'Sales' 'Engineering' 'Finance' 'HR']
# Department
# Sales          209
# Finance        206
# Engineering    204
# HR             191
# Marketing      190
# Name: count, dtype: int64
# ------------------------
# Job_Title:['Manager' 'Engineer' 'Analyst' 'HR Specialist' 'Accountant']
# Job_Title
# Engineer         214
# Manager          206
# Accountant       206
# Analyst          195
# HR Specialist    179
# Name: count, dtype: int64
# ------------------------
# Attrition:['No' 'Yes']
# Attrition
# No     505
# Yes    495
# Name: count, dtype: int64
# ------------------------

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Department',hue='Attrition',data=df, palette='coolwarm')
plt.title('Attrition vs Department')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Years_at_Company',hue='Attrition',data=df, palette='coolwarm')
plt.title('Attrition vs Years')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Job_Title',hue='Attrition',data=df, palette='coolwarm')
plt.title('Attrition vs Title')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Age',hue='Attrition',data=df, palette='coolwarm')
plt.title('Age vs Attrition')
plt.show()

# %%
median_age_by_attrition = df.groupby('Attrition')['Age'].median().reset_index()
fig = sns.kdeplot(data=df, x='Age', hue='Attrition', fill=True)

# %%
plt.figure(figsize=(6,3))
sns.countplot(x='Gender',hue='Attrition',data=df, palette='coolwarm')
plt.title('Attrition vs Gender')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      506
# Female    494
# Name: count, dtype: int64

# %%
df['count']=1
df.groupby(['Gender','Attrition']).agg({'count':'sum'})
# Out:
#                   count
# Gender Attrition
# Female No           241
#        Yes          253
# Male   No           264
#        Yes          242

# %%
#for detecting gender discrimation during attrition
253/(253+241)
# Out:
# 0.5121457489878543

# %%
242/(242+264)
# Out:
# 0.4782608695652174

# %%
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %%
df_numerical = df.select_dtypes(include=['number'])
df_corr = df_numerical.corr()
df_corr
# Out:
#                        Employee_ID       Age    Gender  Years_at_Company  \
# Employee_ID               1.000000  0.013711 -0.002404         -0.001375
# Age                       0.013711  1.000000 -0.036815          0.018837
# Gender                   -0.002404 -0.036815  1.000000         -0.022598
# Years_at_Company         -0.001375  0.018837 -0.022598          1.000000
# Satisfaction_Level       -0.004468  0.021263 -0.053603         -0.032470
# Average_Monthly_Hours     0.031244 -0.031304  0.064458         -0.060726
# Promotion_Last_5Years    -0.038501  0.039444  0.007668         -0.010661
# Salary                   -0.010353 -0.018682  0.071373          0.036053
# count                          NaN       NaN       NaN               NaN
#
#                        Satisfaction_Level  Average_Monthly_Hours  \
# Employee_ID                     -0.004468               0.031244
# Age                              0.021263              -0.031304
# ...

# %%
X=df.drop(['Attrition'],axis=1)
Y=df["Attrition"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((700, 11), (300, 11))

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
categorical_columns = ['Gender', 'Department', 'Job_Title']
for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42, n_estimators=10, max_depth=3)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10, random_state=42)

# %%
# Make predictions on the test set
y_pred = rf.predict(X_test)
y_pred
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No',
#        'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
# ...

# %%
rf.estimators_[0]
# Out:
# DecisionTreeClassifier(max_depth=3, max_features='sqrt',
#                        random_state=1608637542)

# %%
sample_tree = rf.estimators_[4]
sample_tree
# Out:
# DecisionTreeClassifier(max_depth=3, max_features='sqrt', random_state=996406378)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
def evaluate_model(dt_classifier):
    print("Train Accuracy :", accuracy_score(y_train, dt_classifier.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, dt_classifier.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %%
evaluate_model(rf)
# Out:
# Train Accuracy : 0.6128571428571429
# Train Confusion Matrix:
# [[223 126]
#  [145 206]]
# --------------------------------------------------
# Test Accuracy : 0.48
# Test Confusion Matrix:
# [[76 80]
#  [76 68]]

# %%
# Feature Importance
importances = rf.feature_importances_
features = X.columns
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(12, 6))
plt.title("Feature Importances")
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), [features[i] for i in indices], rotation=90)
plt.show()

# %%
# Perform 4-fold cross-validation
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(rf, X, Y, cv=4, scoring='accuracy')
print("Cross-Validation Scores:", cv_score)
print("Mean CV Score:", cv_score.mean())
# Out:
# Cross-Validation Scores: [0.488 0.472 0.484 0.496]
# Mean CV Score: 0.485

# %%
#grid search for hyper parameter tunning
from sklearn.model_selection import GridSearchCV
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
# Create the parameter grid based on the results of random search
params = {
    'max_depth': [1, 2, 5, 10, 20],
    'max_features': [2,3,4],
    'n_estimators': [10, 30, 50, 100, 200]
}

# %%
grid_search = GridSearchCV(estimator=classifier_rf, param_grid=params,cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")
grid_search.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 75 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 5, 10, 20],
#                          'max_features': [2, 3, 4],
#                          'n_estimators': [10, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=10, max_features=2, n_estimators=10, n_jobs=-1,
#                        random_state=42)

# %%
evaluate_model(rf_best)
# Out:
# Train Accuracy : 0.9542857142857143
# Train Confusion Matrix:
# [[333  16]
#  [ 16 335]]
# --------------------------------------------------
# Test Accuracy : 0.4866666666666667
# Test Confusion Matrix:
# [[78 78]
#  [76 68]]

# %%
score_df =pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.055291      0.006445         0.020199        0.001924
# 1       0.103131      0.002010         0.020633        0.001313
# 2       0.159558      0.005939         0.030074        0.007843
# 3       0.349460      0.051847         0.046420        0.017124
# 4       0.912382      0.306662         0.062139        0.017327
#
#    param_max_depth  param_max_features  param_n_estimators  \
# 0                1                   2                  10
# 1                1                   2                  30
# 2                1                   2                  50
# 3                1                   2                 100
# 4                1                   2                 200
#
#                                               params  split0_test_score  \
# 0  {'max_depth': 1, 'max_features': 2, 'n_estimat...           0.502857
# 1  {'max_depth': 1, 'max_features': 2, 'n_estimat...           0.485714
# ...

# %%
score_df.nlargest(5,"mean_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 45       0.047693      0.003554         0.020690        0.001704
# 25       0.050292      0.003645         0.019795        0.000297
# 2        0.159558      0.005939         0.030074        0.007843
# 10       0.040878      0.003492         0.018862        0.000913
# 5        0.048617      0.002061         0.020609        0.001710
#
#     param_max_depth  param_max_features  param_n_estimators  \
# 45               10                   2                  10
# 25                2                   4                  10
# 2                 1                   2                  50
# 10                1                   4                  10
# 5                 1                   3                  10
#
#                                                params  split0_test_score  \
# 45  {'max_depth': 10, 'max_features': 2, 'n_estima...           0.548571
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, rf_best.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.51      0.50      0.50       156
#          Yes       0.47      0.47      0.47       144
#
#     accuracy                           0.49       300
#    macro avg       0.49      0.49      0.49       300
# weighted avg       0.49      0.49      0.49       300

# %%
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz
import pydotplus, graphviz
from graphviz import Digraph

# %%
def get_dt_graph(dt_classifier):
    dot_data = StringIO()
    export_graphviz(dt_classifier, out_file=dot_data, filled=True,rounded=True,
                    feature_names=X.columns,
                    class_names=["Attrition", "No Attrition"])
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    return graph

# %%
gph = get_dt_graph(sample_tree)
Image(gph.create_png())

# %%
gph = get_dt_graph(rf.estimators_[0])
Image(gph.create_png(), width=1500, height=700)

# %%
gph = get_dt_graph(rf.estimators_[2])
Image(gph.create_png(), width=1500, height=700)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Create a dataframe to hold VIF values for each feature
vif_data = pd.DataFrame()
vif_data['Feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
# Step 5: Display VIF results
print(vif_data)
# Out:
#                   Feature        VIF
# 0             Employee_ID   1.003119
# 1                     Age   1.005763
# 2                  Gender   1.015562
# 3              Department   1.009136
# 4               Job_Title   1.006291
# 5        Years_at_Company   1.007482
# 6      Satisfaction_Level   1.005828
# 7   Average_Monthly_Hours   1.015383
# 8   Promotion_Last_5Years   1.011372
# 9                  Salary   1.013420
# 10                  count  96.121556

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='rbf', random_state=42)
# Train the model
svm_model.fit(X_train, y_train)
# Predictions and Evaluation
# Predict the test set results
y_pred = svm_model.predict(X_test)
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Confusion Matrix:
#  [[90 66]
#  [94 50]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.58      0.53       156
#            1       0.43      0.35      0.38       144
#
#     accuracy                           0.47       300
#    macro avg       0.46      0.46      0.46       300
# weighted avg       0.46      0.47      0.46       300
#
# Accuracy: 46.67%

# %%
import pickle
with open('Employee_Attrition_prediction.pkl', 'wb') as f:
    pickle.dump(rf, f)
